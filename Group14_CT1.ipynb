# %% [markdown]
# # Group14 assignment

# %%
import numpy as np
import pandas as pd

# %%
orig_housing_data = pd.read_csv("https://raw.githubusercontent.com/karapradeepkumar/data/main/Real%20Estate%20Data%20V21.csv")
